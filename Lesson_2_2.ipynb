# %% [markdown]
# <div style='font-size:32px; line-height:1.3; font-weight:700;'>🐍 LESSON 2.2</div>
# <div style='font-size:26px; line-height:1.5; margin-top:10px;'>Variables and Addition</div>
#
# <div style='font-size:24px; line-height:1.55; margin-top:20px;'>
# <b>Create these variables:</b><br><br>
# <code>value1</code> gets <code>2.5</code><br>
# <code>value2</code> gets <code>3.25</code><br><br>
# Add them and save the answer as <code>result</code>.
# </div>
#
# <div style='font-size:26px; line-height:1.4; font-weight:700; margin-top:20px;'>WRITE YOUR CODE BELOW ↓</div>

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# <div style='font-size:28px; line-height:1.35; font-weight:700;'>✅ CHECK MY WORK</div>
# <div style='font-size:22px; line-height:1.45;'>Run the next cell.</div>

# %%
from IPython.display import display, HTML

def show_box(title, body, bg, border):
    html = f"""
    <div style="
        font-family:Arial, sans-serif;
        font-size:24px;
        line-height:1.5;
        padding:20px;
        margin:14px 0;
        background:{bg};
        border:4px solid {border};
        border-radius:14px;">
        <div style="font-size:30px; font-weight:700; margin-bottom:12px;">{title}</div>
        {body}
    </div>
    """
    display(HTML(html))

problems = []
correct = []

if 'value1' not in globals():
    problems.append("Create <b>value1</b> and set it to <b>2.5</b>.")
elif value1 != 2.5:
    problems.append(f"<b>value1</b> is {value1!r}. It should be <b>2.5</b>.")
else:
    correct.append("✅ value1")

if 'value2' not in globals():
    problems.append("Create <b>value2</b> and set it to <b>3.25</b>.")
elif value2 != 3.25:
    problems.append(f"<b>value2</b> is {value2!r}. It should be <b>3.25</b>.")
else:
    correct.append("✅ value2")

if 'result' not in globals():
    problems.append("Create <b>result</b> using <b>value1 + value2</b>.")
elif result != 5.75:
    problems.append(f"<b>result</b> is {result!r}. Check the addition.")
else:
    correct.append("✅ result")

if problems:
    body = ""
    if correct:
        body += "<b>Correct:</b> " + " &nbsp; ".join(correct) + "<br><br>"
    body += "<b>Try this next:</b><br>" + "<br><br>".join(problems)
    body += "<br><br>Fix your code, run it again, then check your work again."
    show_box("🛠️ ALMOST THERE", body, "#FFF8E8", "#9A6700")
else:
    show_box(
        "🎉 CORRECT!",
        "✅ value1 = 2.5<br>✅ value2 = 3.25<br>✅ result = 5.75"
        "<br><br><b>Lesson 2.2 complete.</b>",
        "#EAF8EA",
        "#247A24"
    )
